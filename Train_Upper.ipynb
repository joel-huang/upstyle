# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
train_df = pd.read_csv('final_upper.csv').sample(frac=1)
train_df.head()
# Out:
#                                               image_name  graphic  floral  \
# 3719       img/Collared_Surplice_Blouse/img_00000026.jpg        0       1
# 7503   img/Lace-Paneled_Lattice-Back_Blouse/img_00000...        0       0
# 6932   img/Hidden_Zippered_Placket_Blouse/img_0000004...        0       0
# 28200               img/Beaded_Lace_Top/img_00000040.jpg        0       0
# 8782         img/Pintuck_Pleated_Blouse/img_00000092.jpg        0       0
#
#        stripe  dot  knit  denim  leather  lace  chiffon   ...    sheer  \
# 3719        0    0     0      0        0     0        0   ...        0
# 7503        0    0     0      0        0     1        0   ...        0
# 6932        0    0     0      0        0     0        0   ...        0
# 28200       0    0     0      0        0     1        0   ...        0
# 8782        0    0     0      0        0     0        0   ...        0
#
#        cotton  sleeve  sleeveless  collar  pocket  v-neck  button  hooded  \
# ...

# %%
class_list = list(train_df.columns)[1:]
print(len(class_list),class_list)
# Out:
# 20 ['graphic', 'floral', 'stripe', 'dot', 'knit', 'denim', 'leather', 'lace', 'chiffon', 'embroidered', 'sheer', 'cotton', 'sleeve', 'sleeveless', 'collar', 'pocket', 'v-neck', 'button', 'hooded', 'zipper']

# %%
train_idg = ImageDataGenerator()
train_gen = train_idg.flow_from_dataframe(train_df, directory, x_col='image_name', y_col=class_list, classes=class_list, target_size=(224, 224), batch_size = 16)

# %%
model = InceptionV3(weights='imagenet', include_top=False, input_shape=(224,224,3))

# %%
nclass = 19
    
model.trainable = False

x = model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(20, activation='sigmoid')(x)
model = Model(model.input, predictions)
model.compile(loss='categorical_crossentropy', 
              optimizer=optimizers.SGD(lr=1e-4, 
                                       momentum=0.9),
              metrics=['accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 111, 111, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 111, 111, 32) 96          conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 111, 111, 32) 0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 109, 109, 32) 9216        activation_189[0][0]
# ...
